# %% [markdown]
# <a href="https://colab.research.google.com/github/OlegKuzmin1968/Oleg_Kuzmin/blob/main/%D0%A7%D1%82%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B8_%D0%BF%D1%80%D0%BE%D1%81%D0%BC%D0%BE%D1%82%D1%80_DICOM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install pydicom
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 32.2 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pydicom
from PIL import Image

im = pydicom.dcmread('/content/1-001.dcm')
im = im.pixel_array.astype(float)
rescaled_image = (np.maximum(im,0)/im.max())*255
final_image = np.uint8(rescaled_image)

final_image = Image.fromarray(final_image)
final_image.show()
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FD213D8EBC0>
